# %% [markdown]
# <a href="https://colab.research.google.com/github/Goutham-26/DSA/blob/main/22casestudy.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
population = pd.read_csv('/content/population.csv')
population.head()
# Out:
#          country  population
# 0  United States   331002651
# 1          China  1411778724
# 2          India  1380004385
# 3          Japan   125836021
# 4        Germany    83240525

# %%
population.dtypes
# Out:
# country       object
# population     int64
# dtype: object

# %%
population.shape
# Out:
# (25, 2)

# %%
gdp = pd.read_excel('/content/gdp.xlsx')
gdp.columns.tolist()
# Out:
# ['Country', 'GDP']

# %%
gdp.dtypes
# Out:
# Country    object
# GDP         int64
# dtype: object

# %%
internet= pd.read_json('/content/internet_users.json')
internet.head()
# Out:
#          country  internet_users
# 0  United States       312000000
# 1          China      1080000000
# 2          India       850000000
# 3          Japan       118000000
# 4        Germany        79000000

# %%
pd.DataFrame(internet_df)
# Out:
#            country  internet_users
# 0    United States       312000000
# 1            China      1080000000
# 2            India       850000000
# 3            Japan       118000000
# 4          Germany        79000000
# 5   United Kingdom        66000000
# 6           France        62000000
# 7            Italy        56000000
# 8           Canada        36000000
# 9        Australia        24000000
# 10          Brazil       181000000
# 11          Russia       125000000
# 12     South Korea        50000000
# 13           Spain        44000000
# 14          Mexico       102000000
# 15       Indonesia       212000000
# 16    Saudi Arabia        34000000
# 17          Turkey        69000000
# 18    South Africa        43000000
# 19       Argentina        41000000
# 20     Netherlands        17000000
# 21     Switzerland         8500000
# 22          Sweden        10100000
# 23          Norway         5300000
# 24       Singapore         5600000

# %%
literacy = pd.read_xml('/content/literacy_rate.xml')
literacy.head()
# Out:
#             name  literacy_rate
# 0  United States           99.0
# 1          China           97.2
# 2          India           77.7
# 3          Japan           99.0
# 4        Germany           99.0

# %%
pd.DataFrame(literacy)
# Out:
#               name  literacy_rate
# 0    United States           99.0
# 1            China           97.2
# 2            India           77.7
# 3            Japan           99.0
# 4          Germany           99.0
# 5   United Kingdom           99.0
# 6           France           99.0
# 7            Italy           99.0
# 8           Canada           99.0
# 9        Australia           99.0
# 10          Brazil           93.2
# 11          Russia           99.7
# 12     South Korea           98.8
# 13           Spain           98.6
# 14          Mexico           95.4
# 15       Indonesia           96.0
# 16    Saudi Arabia           97.3
# 17          Turkey           96.7
# 18    South Africa           95.0
# 19       Argentina           99.1
# 20     Netherlands           99.0
# 21     Switzerland           99.0
# 22          Sweden           99.0
# 23          Norway          100.0
# 24       Singapore           97.5

# %%
exploration_results = {}

datasets = [
    ("Population Dataset", population),
    ("GDP Dataset", gdp),
    ("Internet Users Dataset", internet),
    ("Literacy Rate Dataset", literacy)
]
for name, df in datasets:
    exploration_results[name] = {
        "num_rows": df.shape[0],
        "num_columns": df.shape[1],
        "column_names": df.columns.tolist(),
        "data_types": df.dtypes.to_dict(),
        "missing_values": df.isnull().sum().to_dict(),
        "duplicate_records": int(df.duplicated().sum())
    }
pd.DataFrame(exploration_results)
# Out:
#                                          Population Dataset  \
# num_rows                                                 25
# num_columns                                               2
# column_names                          [country, population]
# data_types         {'country': object, 'population': int64}
# missing_values              {'country': 0, 'population': 0}
# duplicate_records                                         0
#
#                                          GDP Dataset  \
# num_rows                                          25
# num_columns                                        2
# column_names                          [Country, GDP]
# data_types         {'Country': object, 'GDP': int64}
# missing_values              {'Country': 0, 'GDP': 0}
# duplicate_records                                  0
#
#                                          Internet Users Dataset  \
# num_rows                                                     25
# ...

# %%
population.rename(columns={'country': 'country'}, inplace=True)
gdp.rename(columns={'Country': 'country'}, inplace=True)
internet.rename(columns={'country': 'country'}, inplace=True)
literacy.rename(columns={'name': 'country'}, inplace=True)

# %%
population.columns.tolist()
# Out:
# ['country', 'population']

# %%
gdp.columns.tolist()
# Out:
# ['country', 'GDP']

# %%
internet.columns.tolist()
# Out:
# ['country', 'internet_users']

# %%
literacy.columns.tolist()
# Out:
# ['country', 'literacy_rate']

# %%
merged = population.merge(gdp, on='country', how='inner')
merged = merged.merge(internet, on='country', how='inner')
merged = merged.merge(literacy, on='country', how='inner')
data=pd.DataFrame(merged)
data
# Out:
#            country  population       GDP  internet_users  literacy_rate
# 0    United States   331002651  30500000       312000000           99.0
# 1            China  1411778724  19230000      1080000000           97.2
# 2            India  1380004385   4187000       850000000           77.7
# 3            Japan   125836021   4180000       118000000           99.0
# 4          Germany    83240525   4744000        79000000           99.0
# 5   United Kingdom    67886011   3839000        66000000           99.0
# 6           France    65273511   3211000        62000000           99.0
# 7            Italy    60461826   2420000        56000000           99.0
# 8           Canada    38005238   2250000        36000000           99.0
# 9        Australia    25687041   1880000        24000000           99.0
# 10          Brazil   212559417   2330000       181000000           93.2
# 11          Russia   145934462   2200000       125000000           99.7
# ...

# %%
merged = pd.merge(population, gdp, on='country', how='outer')
merged = pd.merge(merged_df, internet, on='country', how='outer')
merged = pd.merge(merged_df, literacy, on='country', how='outer')

display(merged.head())
# Out:
#      country  population       GDP  internet_users  literacy_rate_x  \
# 0  Argentina    45195774    640000        41000000             99.1
# 1  Australia    25687041   1880000        24000000             99.0
# 2     Brazil   212559417   2330000       181000000             93.2
# 3     Canada    38005238   2250000        36000000             99.0
# 4      China  1411778724  19230000      1080000000             97.2
#
#    literacy_rate_y
# 0             99.1
# 1             99.0
# 2             93.2
# 3             99.0
# 4             97.2

# %%
merged['internet_penetration'] = round((merged['internet_users'] / merged['population']) * 100, 2)
merged['gdp_per_capita'] = round(merged['GDP'] / merged['population'], 2)

# %%
merged['internet_penetration']
# Out:
# 0     90.72
# 1     93.43
# 2     85.15
# 3     94.72
# 4     76.50
# 5     94.98
# 6     94.91
# 7     61.59
# 8     77.51
# 9     92.62
# 10    93.77
# 11    79.11
# 12    97.47
# 13    97.76
# 14    85.65
# 15    97.66
# 16    95.72
# 17    72.50
# 18    96.56
# 19    94.11
# 20    97.55
# 21    98.21
# 22    81.81
# 23    97.22
# 24    94.26
# Name: internet_penetration, dtype: float64

# %%
merged['gdp_per_capita']
# Out:
# 0     0.01
# 1     0.07
# 2     0.01
# 3     0.06
# 4     0.01
# 5     0.05
# 6     0.06
# 7     0.00
# 8     0.01
# 9     0.04
# 10    0.03
# 11    0.01
# 12    0.07
# 13    0.11
# 14    0.02
# 15    0.03
# 16    0.09
# 17    0.01
# 18    0.03
# 19    0.04
# 20    0.06
# 21    0.11
# 22    0.02
# 23    0.06
# 24    0.09
# Name: gdp_per_capita, dtype: float64

# %%
import sqlite3
conn = sqlite3.connect('country_analytics.db')
merged.to_sql('country_statistics', conn, if_exists='replace', index=False)
# Out:
# 25

# %%
verification = pd.read_sql_query("SELECT * FROM country_statistics LIMIT 5;", conn)
verification
# Out:
#      country  population       GDP  internet_users  literacy_rate_x  \
# 0  Argentina    45195774    640000        41000000             99.1
# 1  Australia    25687041   1880000        24000000             99.0
# 2     Brazil   212559417   2330000       181000000             93.2
# 3     Canada    38005238   2250000        36000000             99.0
# 4      China  1411778724  19230000      1080000000             97.2
#
#    literacy_rate_y  internet_penetration  gdp_per_capita
# 0             99.1                 90.72            0.01
# 1             99.0                 93.43            0.07
# 2             93.2                 85.15            0.01
# 3             99.0                 94.72            0.06
# 4             97.2                 76.50            0.01

# %%
top_5_gdp = merged.nlargest(5, 'GDP')[['country', 'GDP']]
top_5_gdp
# Out:
#           country       GDP
# 24  United States  30500000
# 4           China  19230000
# 6         Germany   4744000
# 7           India   4187000
# 10          Japan   4180000

# %%
top_5_population = merged.nlargest(5, 'population')[['country', 'population']]
top_5_population
# Out:
#           country  population
# 4           China  1411778724
# 7           India  1380004385
# 24  United States   331002651
# 8       Indonesia   273523615
# 2          Brazil   212559417

# %%
average_literacy = merged['literacy_rate_y'].mean()
average_literacy
# Out:
# np.float64(97.24799999999999)

# %%
high_literacy = merged[merged['literacy_rate_y'] > 90][['country', 'literacy_rate_y']]
high_literacy
# Out:
#            country  literacy_rate_y
# 0        Argentina             99.1
# 1        Australia             99.0
# 2           Brazil             93.2
# 3           Canada             99.0
# 4            China             97.2
# 5           France             99.0
# 6          Germany             99.0
# 8        Indonesia             96.0
# 9            Italy             99.0
# 10           Japan             99.0
# 11          Mexico             95.4
# 12     Netherlands             99.0
# 13          Norway            100.0
# 14          Russia             99.7
# 15    Saudi Arabia             97.3
# 16       Singapore             97.5
# 17    South Africa             95.0
# 18     South Korea             98.8
# 19           Spain             98.6
# 20          Sweden             99.0
# 21     Switzerland             99.0
# 22          Turkey             96.7
# 23  United Kingdom             99.0
# 24   United States             99.0

# %%
high_internet_penetration = merged[merged['internet_penetration'] > 70][['country', 'internet_penetration']]
high_internet_penetration
# Out:
#            country  internet_penetration
# 0        Argentina                 90.72
# 1        Australia                 93.43
# 2           Brazil                 85.15
# 3           Canada                 94.72
# 4            China                 76.50
# 5           France                 94.98
# 6          Germany                 94.91
# 8        Indonesia                 77.51
# 9            Italy                 92.62
# 10           Japan                 93.77
# 11          Mexico                 79.11
# 12     Netherlands                 97.47
# 13          Norway                 97.76
# 14          Russia                 85.65
# 15    Saudi Arabia                 97.66
# 16       Singapore                 95.72
# 17    South Africa                 72.50
# 18     South Korea                 96.56
# 19           Spain                 94.11
# 20          Sweden                 97.55
# 21     Switzerland                 98.21
# 22          Turkey                 81.81
# ...

# %%
top_5_gdp_per_capita = merged.nlargest(5, 'gdp_per_capita')[['country', 'gdp_per_capita']]
top_5_gdp_per_capita
# Out:
#           country  gdp_per_capita
# 13         Norway            0.11
# 21    Switzerland            0.11
# 16      Singapore            0.09
# 24  United States            0.09
# 1       Australia            0.07

# %%
total_population = merged['population'].sum()
total_population
# Out:
# np.int64(4720039725)

# %%
average_internet_penetration = merged['internet_penetration'].mean()
average_internet_penetration
# Out:
# np.float64(89.65960000000001)

# %%
highest_internet_country = merged.loc[merged['internet_users'].idxmax(), ['country', 'internet_users']]
highest_internet_country
# Out:
# country                China
# internet_users    1080000000
# Name: 4, dtype: object

# %%
correlation_metric = merged['literacy_rate_y'].corr(merged['internet_penetration'])
correlation_metric
# Out:
# np.float64(0.7727975681398502)

# %%
conn = sqlite3.connect('country_analytics.db')
cursor = conn.cursor()

# %%
q1 = "SELECT country, GDP FROM country_statistics ORDER BY GDP DESC LIMIT 5;"
cursor.execute(q1)
for row in cursor.fetchall():
    print(row)
# Out:
# ('United States', 30500000)
# ('China', 19230000)
# ('Germany', 4744000)
# ('India', 4187000)
# ('Japan', 4180000)

# %%
q2 = "SELECT AVG(literacy_rate_y) FROM country_statistics;"
cursor.execute(q2)
print(f"Average Literacy Rate: {cursor.fetchone()[0]:.3f}%")
# Out:
# Average Literacy Rate: 97.248%

# %%
q3 = "SELECT country, literacy_rate_y FROM country_statistics WHERE literacy_rate_y > 90;"
cursor.execute(q3)
for row in cursor.fetchall():
    print(row)
# Out:
# ('Argentina', 99.1)
# ('Australia', 99.0)
# ('Brazil', 93.2)
# ('Canada', 99.0)
# ('China', 97.2)
# ('France', 99.0)
# ('Germany', 99.0)
# ('Indonesia', 96.0)
# ('Italy', 99.0)
# ('Japan', 99.0)
# ('Mexico', 95.4)
# ('Netherlands', 99.0)
# ('Norway', 100.0)
# ('Russia', 99.7)
# ('Saudi Arabia', 97.3)
# ('Singapore', 97.5)
# ('South Africa', 95.0)
# ('South Korea', 98.8)
# ('Spain', 98.6)
# ('Sweden', 99.0)
# ('Switzerland', 99.0)
# ('Turkey', 96.7)
# ('United Kingdom', 99.0)
# ('United States', 99.0)

# %%
q4 = "SELECT country, internet_penetration FROM country_statistics ORDER BY internet_penetration DESC LIMIT 5;"
cursor.execute(q4)
for row in cursor.fetchall():
    print(row)
# Out:
# ('Switzerland', 98.21)
# ('Norway', 97.76)
# ('Saudi Arabia', 97.66)
# ('Sweden', 97.55)
# ('Netherlands', 97.47)

# %%
q5 = "SELECT SUM(population) FROM country_statistics;"
cursor.execute(q5)
print(f"Total Population: {cursor.fetchone()[0]}")
# Out:
# Total Population: 4720039725

# %%
q6 = "SELECT country, gdp_per_capita FROM country_statistics ORDER BY gdp_per_capita DESC LIMIT 1;"
cursor.execute(q6)
print(f"ountry with Highest GDP per Capita: {cursor.fetchone()}")
# Out:
# ountry with Highest GDP per Capita: ('Norway', 0.11)

# %%
export = pd.read_sql_query("SELECT * FROM country_statistics;", conn)
export.to_csv('final_country_statistics.csv', index=False)
print("\n17. Final dataset successfully exported to 'final_country_statistics.csv'")
# Out:
# 17. Final dataset successfully exported to 'final_country_statistics.csv'

# %%
q8 = "SELECT country, gdp_per_capita FROM country_statistics ORDER BY gdp_per_capita DESC LIMIT 10;"
cursor.execute(q8)
print("Top 10 Countries by GDP per Capita:")
for row in cursor.fetchall():
    print(row)
# Out:
# Top 10 Countries by GDP per Capita:
# ('Norway', 0.11)
# ('Switzerland', 0.11)
# ('Singapore', 0.09)
# ('United States', 0.09)
# ('Australia', 0.07)
# ('Netherlands', 0.07)
# ('Canada', 0.06)
# ('Germany', 0.06)
# ('Sweden', 0.06)
# ('United Kingdom', 0.06)

# %%
cursor.close()
conn.close()
